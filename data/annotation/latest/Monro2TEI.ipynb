# %%
import re

f = open('monro-work.xml')
outf = open('monro-tei.xml','w')
for l in f:
    l = re.sub('\s+$','',l)
    
    print(l)


f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-3259cd5c782e> in <module>
#       1 import re
#       2
# ----> 3 f = open('monro-work.xml')
#       4 outf = open('monro-tei.xml','w')
#       5 for l in f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'monro-work.xml'
